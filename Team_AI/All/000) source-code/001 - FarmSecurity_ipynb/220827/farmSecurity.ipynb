# %% [markdown]
# # 참고 사이트 목록
#
# 전체적 설명 관련 참고 사이트
# https://velog.io/@jhlee508/Object-Detection-YOLOv4-Darknet-%ED%95%99%EC%8A%B5%ED%95%98%EC%97%AC-Custom-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%9D%B8%EC%8B%9D-%EB%AA%A8%EB%8D%B8-%EB%A7%8C%EB%93%A4%EA%B8%B0-feat.-AlexeyABdarknet
#
# 코드 관련 참고 사이트
# https://colab.research.google.com/drive/1_GdoqCJWXsChrOiY8sZMr_zbr_fH-0Fg?usp=sharing#scrollTo=fGKcGR_kZAU7
#
# 경로 관련 참고 사이트
# https://velog.io/@jhlee508/Object-Detection-YOLOv4-Darknet-%ED%95%99%EC%8A%B5%ED%95%98%EC%97%AC-Custom-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%9D%B8%EC%8B%9D-%EB%AA%A8%EB%8D%B8-%EB%A7%8C%EB%93%A4%EA%B8%B0-feat.-AlexeyABdarknet
#
# 학습 관련 참고 사이트 https://m.blog.naver.com/bigdata-pro/221781790878

# %% [markdown]
# # Driver 연결

# %% [markdown]
# ## 초기 디렉터리 연결시 사용

# %%
# 초기 디렉터리 연결시 사용
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 갑자기 디렉토리 사용불가능 할 때 사용

# %%
#갑자기 디렉토리 사용불가능 할 때 사용
import os
path = "/content" 
os.chdir(path)

# %% [markdown]
# ## remount해야할 때 사용

# %%
#remount해야할 때 사용
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# # 경로 이동 & darknet 다운로드

# %% [markdown]
# ## 경로 이동
#
# - 먼저 아래 코드 실행 전에 /content/drive/MyDrive 안에 yolov4 폴더를 직접 생성한 후 아래 코드 블럭 실행할 것

# %%
# %cd /content/drive/MyDrive/yolov4/

# %% [markdown]
# ## darknet 다운로드
#
# yolov4 폴더에 darknet 설치

# %%
# !git clone https://github.com/AlexeyAB/darknet.git /content/drive/MyDrive/yolov4/

# %% [markdown]
# # Make 파일 생성 및 수정

# %% [markdown]
# ## 생성 및 수정

# %%
# change makefile to have GPU and OPENCV enabled
# %cd /content/drive/MyDrive/yolov4/
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile

# %% [markdown]
# ## GPU 버전 확인 (설치 확인)

# %%
# !/usr/local/cuda/bin/nvcc --version

# %% [markdown]
# ## make 실행

# %%
# !make

# %% [markdown]
# # 사전 작업

# %% [markdown]
# yolov4.conv.137<br>
# yolov4-custom.cfg<br>
# yolov4-obj.cfg<br><br>
#
# 파일 미리 다운로드 또는 생성하여 대입되어야 되는 경로에 대입할 것<br>
# 상세 설명은 아래 텍스트 셀을 보면서 참고할 것

# %% [markdown]
# ###  yolov4.conv.137 파일
#
# 1. Pre-trained Weight 파일에 해당<br>
# @ 아래 사이트에서 다운로드 할 것<br>
# > https://drive.google.com/open?id=1JKF-bdIklxOOVy-2Cr5qdvjgGpmGfcbp
#
#
# 2. 다운로드 후 아래 경로에 저장할 것<br>
# @ darknet/build/darknet/x64 경로 내에 둔다.<br>
# > ex) /content/drive/MyDrive/yolov4/build/darknet/x64/yolov4.conv.137

# %% [markdown]
# ### cfg 파일 설정하기
#
# configure 파일을 설정하는 단계
#
# 1. darknet/cfg/yolov4-custom.cfg and  darknet/cfg/yolov4-obj.cfg
#
#     Clone 받은 darket 파일에서 위 경로 내에 있는 yolov4-custom.cfg 라는 이름의 cfg 파일을 통째로 복사하여<br> yolov4-obj.cfg 라는 이름으로 같은 경로 내에 복사본을 생성한다.<br>
#     yolov4-obj.cfg 라는 이름의 빈 파일을 먼저 생성하고 yolov4-custom.cfg 파일의 내용을 복사해도 된다.<br><br>
#
#     즉, 파일 구조는 아래와 같다.<br>
#
#         darknet
#         ㄴ cfg
#         ㄴ yolov4-custom.cfg
#         ㄴ yolov4-obj.cfg
#         ㄴ ...
#         ㄴ ...
#
#
# 2. yolov4-obj.cfg 파일 및 yolov4-custom.cfg 파일 내용을 수정
#
#     - 6번째 line을 batch=64로 수정<br>
#     - 7번째 line을 subdivision=16로 수정<br>
#     - 20번째 line을 max_batches={클래수 개수*2000}로 수정<br>
#     ex) 만약 클래스의 개수가 2개라면 max_batches=4000<br>
#     - 22번째 line을 steps={클래스 개수*2000*0.80},{클래스 개수*2000*0.90}로 수정<br>
#     ex) 만약 클래스 개수가 2개라면 steps=3200,3600<br>
#     - 8번째, 9번째 line을 원하는 네트워크 input size로 수정<br>
#     ex) 416x416 크기의 이미지를 입력하려면 width=416, height=416 (32의 배수로 설정하는 것을 권장)<br>
#     - [yolo] layer에 해당하는 970번째, 1058번째, 1146번째 3개의 line을 모두 classes={클래스 개수}로 수정<br>
#     ex) 만약 클래스의 개수가 2개라면 classes=2<br>
#     - 3개의 [yolo] layer 직전의 [convolution] layer의 해당하는 963번째, 1051번째, 1139번째 line을 모두 filters={(클래수 개수 + 5) x 3}로 수정<br>
#     ex) 만약 클래스의 개수가 2개라면 filters=21

# %% [markdown]
# # 이미지와 라벨링 파일 저장하기
#
# 전체 이미지 파일과 라벨링 파일을 모두 /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj 경로에 넣어준다.<br> obj 폴더가 /content/drive/MyDrive/yolov4/build/darknet/x64/data 경로 내에 없다면 obj 폴더 생성 후 파일들을 집어 넣어준다.<br>
#
# ex)<br>
#
#     darknet
#     ㄴ build
#     ㄴ darknet
#         ㄴ x64
#             ㄴ data
#                 ㄴ obj
#                 ㄴ img1.jpg
#                 ㄴ img1.txt
#                 ㄴ img2.jpg
#                 ㄴ img2.txt
#                 ㄴ ...
#
# <주의><br> 이미지 파일과 라벨링 파일의 이름은 둘이 일치하기만 하다면 어떻게 설정하든지 상관없다.<br> 또한 train 이미지와 valid 이미지 모두 darknet/build/darknet/x64/data/obj/ 경로 내에 넣어주면 된다.

# %% [markdown]
# # 필요 사용자 정의 함수

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

def makefile():
  import random as rd
  import os

  files = os.listdir('data/farm')
  rd.shuffle(files)

  files = ['/data/farm/'+i for i in files]

  len(files)

  #f = open("data/train.txt", 'w',encoding='UTF-8')
  f1 = open("data/validation.txt", 'w',encoding='UTF-8')
  count = 0
  for file in files:
      if file.split('.')[-1] =='txt':
          pass
      else:
          if count > len(files)*0.4:
              f1.write(file+'\n')
          count +=1

  #f.close()
  f1.close()

# %% [markdown]
# # train.txt, valid.txt 파일 생성 및 저장하기
# 이미지의 경로가 지정되어 있는 train.txt 파일과 test.txt 파일을 생성하고 저장하는 단계이다.<br> 각각의 파일은 학습과 검증에 사용될 이미지의 상대 혹은 절대 경로를 저장하고 있다.<br>
#
# 여러 방법이 있겠지만 아래의 방법을 따라하면 쉽게 진행할 수 있다.<br><br>

# %% [markdown]
# ## 1st
# 먼저, glob 라이브러리를 활용하여 경로를 이전에 저장한 이미지들의 경로를 리스트 형태로 생성한다.<br> 아래의 코드에서 이미지 경로 설정에 주의한다.

# %%
#사진들은 다 /darknet/build/darknet/x64/data/obj에 저장하고
#아래는 저장된 사진들의 갯수를 가져옴
from glob import glob

#class별로 list 구분!(22.08.21)
animal_img_list = glob('/content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/animal*.jpg')
bird_img_list =  glob('/content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/bird*.jpg')
human_img_list =  glob('/content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/human*.jpg')
print(len(animal_img_list))
print(len(bird_img_list))
print(len(human_img_list))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2nd
# 다음, sklearn 라이브러리의 train_test_split 함수를 사용하여 학습과 검증에 사용할 이미지를 분할한다.

# %%
#가져온 사진을 토대로 train, validation, test set 나누기(6:2:2)
from sklearn.model_selection import train_test_split

print('animal')
animal_train_img_list, animal_test_img_list = train_test_split(animal_img_list, test_size=0.4, random_state=42) # random_state는 임의로 선택
print(len(animal_train_img_list), len(animal_test_img_list))

animal_test_img_list, animal_val_img_list = train_test_split(animal_test_img_list, test_size=0.5, random_state=42)
print(len(animal_test_img_list), len(animal_val_img_list))

print('bird')
bird_train_img_list, bird_test_img_list = train_test_split(bird_img_list, test_size=0.4, random_state=42) # random_state는 임의로 선택
print(len(bird_train_img_list), len(bird_test_img_list))

bird_test_img_list, bird_val_img_list = train_test_split(bird_test_img_list, test_size=0.5, random_state=42)
print(len(bird_test_img_list), len(bird_val_img_list))

print('human')
human_train_img_list, human_test_img_list = train_test_split(human_img_list, test_size=0.4, random_state=42) # random_state는 임의로 선택
print(len(human_train_img_list), len(human_test_img_list))

human_test_img_list, human_val_img_list = train_test_split(human_test_img_list, test_size=0.5, random_state=42)
print(len(human_test_img_list), len(human_val_img_list))

# %% [markdown]
# ## 3rd
# 이제 학습 이미지 리스트와 검증 이미지 리스트를 각각 train.txt와 test.txt 파일에 저장한다.<br> 각각의 txt 파일의 경로는 darknet/build/darknet/x64/data/ 경로 아래에 둔다.<br> 경로 설정에 주의한다.<br><br>
#
# ex) 즉, train.txt와 test.txt의 파일의 내용은 예를 들어 아래와 같이 구성된다.<br>
#     /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/img1.jpg<br>
#     /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/img2.jpg<br>
#     /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/img3.jpg<br>
#     ...

# %%
#나눠진 set들을 train.txt, valid.txt, test.txt에 경로, 이름 저장
# animal, bird, human 나눠서

#animal
with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/animal_train.txt', 'w') as f:
    f.write('\n'.join(animal_train_img_list) + '\n')

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/animal_valid.txt', 'w') as f:
    f.write('\n'.join(animal_val_img_list) + '\n')

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/animal_test.txt', 'w') as f:
    f.write('\n'.join(animal_test_img_list) + '\n')



#bird
with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/bird_train.txt', 'w') as f:
    f.write('\n'.join(bird_train_img_list) + '\n')

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/bird_valid.txt', 'w') as f:
    f.write('\n'.join(bird_val_img_list) + '\n')

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/bird_test.txt', 'w') as f:
    f.write('\n'.join(bird_test_img_list) + '\n')



#human
with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/human_train.txt', 'w') as f:
    f.write('\n'.join(human_train_img_list) + '\n')

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/human_valid.txt', 'w') as f:
    f.write('\n'.join(human_val_img_list) + '\n')

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/human_test.txt', 'w') as f:
    f.write('\n'.join(human_test_img_list) + '\n')

# %% [markdown]
# 나눠진 animal_train.txt, bird_train.txt, human_train.txt<br>
#  animal_valid.txt, bird_valid.txt, human_valid.txt<br>
#   animal_test.txt, bird_test.txt, human_test.txt<br>
#   들을 train.txt, valid.txt, test.txt로 합친 후 진행.

# %%
# %cd /content/drive/MyDrive/yolov4/build/darknet/x64/data/

# %%
filenames = ['animal_train.txt', 'bird_train.txt', 'human_train.txt']

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/train.txt', 'w') as outfile:
    for filename in filenames:
        with open(filename) as file:
            outfile.write(file.read())

# %%
filenames = ['animal_test.txt', 'bird_test.txt', 'human_test.txt']

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/test.txt', 'w') as outfile:
    for filename in filenames:
        with open(filename) as file:
            outfile.write(file.read())

# %%
filenames = ['animal_valid.txt', 'bird_valid.txt', 'human_valid.txt']

with open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/valid.txt', 'w') as outfile:
    for filename in filenames:
        with open(filename) as file:
            outfile.write(file.read())

# %% [markdown]
# ## 현재 경로 확인

# %%
# %cd /content/drive/MyDrive/yolov4/

# %%
# !pwd

# %% [markdown]
# # 데이터 파일 생성하기
#
# 이제 학습을 하기 위한 데이터들의 관한 정보를 담고 있는 obj.names, obj.data 파일 2개를 만드는 단계이다.

# %% [markdown]
# ## 1st
# /content/drive/MyDrive/yolov4/build/darknet/x64/data/ 경로 아래에 obj.names 라는 파일을 생성한다.<br>
# obj.names 파일에는 모든 클래스의 이름이 들어간다.<br><br>
#
# ex) 만약 클래스의 개수가 2개이고 각각, dog 와 cat이라면, obj.names 파일의 내용은 아래와 같이 구성된다.
#
#     dog
#     cat

# %% [markdown]
# ## 2nd
# /content/drive/MyDrive/yolov4/build/darknet/x64/data/ 경로 아래에 obj.data 라는 파일을 생성한다.<br>
#
# obj.data 파일의 내용은<br>
# 1) 클래스의 개수,<br>
# 2) train.txt 파일 경로,<br>
# 3) test.txt 파일 경로,<br>
# 4) obj.names 파일 경로,<br>
# 5) 학습된 weight 파일을 백업할(저장할) 경로<br>
# 총 5가지 line으로 구성된다.<br><br>
#
# ex) 즉, obj.data 파일의 내용은 아래와 같이 구성된다.<br>
#
# classes = 2<br>
# train = data/train.txt<br>
# valid = data/test.txt<br>
# names = data/obj.names<br>
# backup = backup

# %% [markdown]
# ## 주의사항
#
# 위 파일의 경로 설정에 매우 주의하도록 한다.<br> 학습 시 train.txt , test.txt 나 obj.names 파일을 찾지 못하는 오류가 발생한다면<br> 상대 경로 말고 절대 경로로 지정해도 된다.<br><br>
#
# 절대 경로로 지정시 obj.data의 내용은 아래와 같이 된다.<br>
#
# classes = 2<br>
# train = /content/drive/MyDrive/yolov4/build/darknet/x64/data/train.txt<br>
# valid = /content/drive/MyDrive/yolov4/build/darknet/x64/data/test.txt<br>
# names = /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.names<br>
# backup = /content/drive/MyDrive/yolov4/build/darknet/x64/backup<br>

# %% [markdown]
# # 훈련(train)

# %% [markdown]
# ## 현재 경로 확인

# %%
# !pwd

# %% [markdown]
# ## 권한 에러 발생시 시행

# %%
#권한 에러 발생시 실행
# !chmod +x ./darknet

# %% [markdown]
# ## 훈련 실행 코드
#
# - !./darknet detector train {obj.data 경로} {yolov4-obj.cfg 경로} {yolov4.conv.137 경로} -dont_show
# - 상대 경로보다는 절대 경로로 하는 것이 에러가 발생하지 않음
# - error message를 확인하지 않으려면 위와 같이 -dont_show 옵션을 입력하는 것이 좋다.
# -map 옵션을 입력하여 학습 그래프를 확인해볼 수도 있다

# %% [markdown]
# ### 초기 학습 시

# %% [markdown]
# ### 학습 효과 올리기
#
# #### 학습 전<br>
# 1. cfg 파일 맨 아래 random=1로 수정
# 2. height, width=608
# 3. height, width가 416으로 설정되어 있을 경우<br>
# layers=23 instead of Line 895: layers=54<br>
# stride=4 instead of Line 892: stride=2<br>
# stride=4 instead of Line 989: stride=2<br>
# 4. 좌우 구별 감지를 원할 경우 Line 17: flip=0 입력
# 5. anchors 크기를 아래의 코드로 재계산해서 cfg 마지막 부분 3군데를 수정<br>
# { darknet.exe detector calc_anchors data/obj.data -num_of_clusters 9 -width 416 -height 416 }
#
# #### 학습 후<br>
# 1. cfg 파일에서 height와 width를 608 혹은 832로 수정.<br>
# 2. Out of Memory 오류가 생기면 subdivision을 16, 32, 64로 수정.<br>
#
# https://github.com/AlexeyAB/darknet에서 물체 감지를 개선하는 방법 참고

# %%
#anchors 크기를 재계산하기
# !./darknet detector calc_anchors /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data -num_of_clusters 9 -width 416 -height 416

# %%
# !./darknet detector train /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data /content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolov4/build/darknet/x64/yolov4.conv.137 -dont_show -map

# %% [markdown]
# ### 초기 train 중 멈추거나 끊겼을 경우
#
# 아래 코드 통해 이어서 진행
#
# - 초기 훈련 코드 블락에 있던 /content/drive/MyDrive/yolov4/build/darknet/x64/yolov4.conv.137 자리가 /content/drive/MyDrive/yolov4/build/darknet/x64/backup/yolov4-custom_last.weights로 변경됨
# - 초기 훈련 실행시 /content/drive/MyDrive/yolov4/build/darknet/x64/backup 안에 여러 weights 확장자 파일이 만들어지게 됨. 그 중 yolov4-custom_last.weights의 경로를 가져오면 됨

# %%
# !./darknet detector train /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data /content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolov4/build/darknet/x64/backup/yolov4-custom_last.weights  -dont_show -map

# %% [markdown]
# # 발생 가능 에러 및 처리
#
# > couldn't open file: train.txt
# > 참고 링크 : https://github.com/pjreddie/darknet/issues/484
#
# obj.data 파일에서 기존 형태는
#
# classes = 2<br>
# train = data/train.txt<br>
# valid = data/test.txt<br>
# names = data/obj.names<br>
# backup = backup/<br>
#
# 일 것이다.<br> 이 상태에서 룬련 코드를 실행했을 때, couldn't open file: train.txt와 같은 에러가 뜬다면<br> 상대 경로가 아닌 절대 경로를 대입해주어야 한다.<br>기왕 하는 것 train.txt 관련만 수정하지 말고 모두 수정해주면 좋을 것이다.
# <br> 그리고 backup = backup/에서 /는 없애는 것이 좋다.
# 수정한 코드는 다음과 같다.
#
# classes = 2<br>
# train = /content/drive/MyDrive/yolov4/build/darknet/x64/data/train.txt<br>
# valid = /content/drive/MyDrive/yolov4/build/darknet/x64/data/test.txt<br>
# names = /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.names<br>
# backup = /content/drive/MyDrive/yolov4/build/darknet/x64/backup<br>

# %% [markdown]
# ### 훈련을 중지해야하는 시점
# 1. 훈련을 하는 동안 다양한 오류 표시기가 표시되며 더이상 0.XXXXXXXX avg가 감소하지 않을 때
#
# 2. 훈련이 중단되면 마지막 파일 중 일부를 가져와서 .weights중에 가장 좋은 것을 선택해야 한다.
#
# ### Early Stopping Point에서 가중치 얻는 법
# 0. obj.data에서 vaild=vaild.txt를 지정하고
#
#     0.1. valid image가 없으면 data/train.txt를 data/vaild.txt에 복사해서 사용한다.
#
#
# 1. obj.data에서 유해성 검사 데이터 세트의 경로를 지정해야한다. 최대 가중치가 9000일 경우, 각 가중치(7000, 8000, 9000)에 대한 마지막 출력 라인을 비교한다.
#
#     - !./darknet detector map {obj.data경로} {yolov4-obj.cfg 경로} {확인하려는 가중치 경로}
#
# 2. 가장 큰 mAP(평균 정밀도)나 IOU(교집합 교차)를 가진 가중치를 통해서 감지에 사용한다.
#
#     - !./darknet detector map {obj.data경로} {yolov4-obj.cfg 경로} {yolov4.conv.137경로}

# %%
# !./darknet detector map /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data /content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolov4/build/darknet/x64/backup/yolov4-custom_6000.weights

# %% [markdown]
# # 실험(test)

# %% [markdown]
# ## 경로 확인

# %%
# %cd /content/drive/MyDrive/yolov4

# %%
# !pwd

# %% [markdown]
# ## 권한

# %%
# !chmod +x ./darknet

# %% [markdown]
# ## 실험 실행 코드

# %% [markdown]
# ### 실험 실행
# - 실험 실행 코드 : !./darknet detector test {obj.data 경로} {yolov4-obj.cfg 경로} {학습된 weight 파일 경로} {테스트 이미지 파일 경로}
# - 코드 실행 결과로 predictions.jpg 파일이 생성된다.
# - 실험 실행 코드를 실행하기에 없어 테스트 이미지를 넣기 위한 폴더를 생성해야 함
# - 해당 폴더는 /content/drive/MyDrive/yolov4/build/darknet/x64/data에 생성할 것
# - 여기서는 farm 폴더로 생성했고 절대 경로는 /content/drive/MyDrive/yolov4/build/darknet/x64/data/farm 이다.
# - 또 test하고자 하는 이미지를 farm 폴더 안에 넣어준다.

# %%
# !./darknet detector test /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data /content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolov4/build/darknet/x64/backup/yolov4-custom_6000.weights /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/animal1.jpg -thresh 0.6

# %% [markdown]
# ### test set 활용해서 mAP 측정하기
# 앞의 weights들의 mAP 비교를 통해 정해진 weights로 최종 성능평가
#
# 해당 셀들을 실행시 얻을 수 있는 것
# - 클래스 당 AP 및 precision, recall
# - mAP
# - detection results 그래프
# - log-average miss rate 그래프
#
# 참고: https://keyog.tistory.com/44

# %% [markdown]
# yolov4 폴더에 mAP 폴더 clone

# %%
# !git clone https://github.com/Cartucho/mAP.git

# %% [markdown]
# darknet 폴더에 result.txt로 해당 test.txt의 detection 결과를 추출
#
# 코드: !./darknet detector test {obj.data 경로} {yolov4-custom.cfg경로} {선택한 weights 파일 경로} -dont_show -ext_output < {test.txt경로} > result.txt

# %%
# !./darknet detector test /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data /content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolov4/build/darknet/x64/backup/yolov4-custom_6000.weights -dont_show -ext_output < /content/drive/MyDrive/yolov4/build/darknet/x64/data/test.txt > result.txt

# %% [markdown]
# ※블로그를 따라해도 detection-results에 .txt 파일이 저장되지 않을 때는 darknet 폴더에 result.txt를 수정해야한다.
#
# 'Enter Image Path :' 의 뒷 부분에는 Detection layer에 관한 설명이 있는데 result.txt를 다운받아서 해당 문자를 모두찾기-공백을 바꾸면 된다.

# %%
# !cp /content/drive/MyDrive/yolov4/result.txt /content/drive/MyDrive/yolov4/mAP/scripts/extra

# %%
# !rm -rf /content/drive/MyDrive/yolov4/mAP/input/detection-results/*

# %%
# %cd /content/drive/MyDrive/yolov4/mAP/scripts/extra 
# !python convert_dr_yolo.py #해당 python 파일안에서 mAP/scripts/extra/result.txt파일 경로를 지정해줘야함

# %% [markdown]
# mAP/scripts/extra 폴더 안에 class_list를 데이터의 객체이름으로 변경하기
#
#
#
# 기존에 있던 파일 전부 삭제 및 이미지 폴더 생성

# %%
# %cd /content/drive/MyDrive/yolov4/mAP
#!rm -rf input/detection-results/*
# !rm -rf input/ground-truth/*
# !rm -rf input/images-optional
#!mkdir input/images
# !rm -rf input/images/*

# %% [markdown]
# ground-truth 데이터와 images 데이터 이동
#
# - ground-truth는 test dataset .txt파일이 저장되고 images는 test dataset .jpg 파일이 저장된다.
#
# 문제점: test dataset .txt 파일들을 따로 구분시켜놓고 해당 코드를 실행해야한다...

# %% [markdown]
# /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/animal159.jpg

# %%
# 1. test.txt에 저장된 .jpg 경로를 통해서 실제 test .jpg만을 저장
# 2. test.txt에 저장된 .jpg를 .txt 경로로 바꾸고 실제 test .txt만을 저장
import shutil
file_path = open('/content/drive/MyDrive/yolov4/build/darknet/x64/data/test.txt')
while True:
    f = file_path.readline().rstrip()
    if not f:
        break
    shutil.copy2(f, '/content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/testset')
    f = f.replace('.jpg', '.txt')
    shutil.copy2(f, '/content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/testset')

# %%
# !cp /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/testset/*.txt /content/drive/MyDrive/yolov4/mAP/input/ground-truth
# !cp /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj/testset/*.jpg /content/drive/MyDrive/yolov4/mAP/input/images

# %% [markdown]
# 이동 되었으면 다시 convert 파일 실행

# %%
# %cd /content/drive/MyDrive/yolov4/mAP/scripts/extra
# !python convert_gt_yolo.py

# %% [markdown]
# mAP/input/ground-truth 폴더 안에 backup이란 폴더가 있다면 잘 convert된 것이다.
#
# mAP/main.py를 열어서 50번째 줄을 수정한다.
# <pre>
# IMG_PATH = os.path.join(os.getcwd(), 'input', 'images')
# <code>

# %% [markdown]
# X 서버에 연결할 수 없다고 뜬다.
# main.py에서 show, Imshow 같은 그래프, 이미지를 보여주려는 부분을 삭제한다.

# %%
# %cd /content/drive/MyDrive/yolov4/mAP
# !python main.py

# %% [markdown]
# ### 실험한 이미지 확인
#
# - 위 실험 코드를 실행하면 predictions.jpg 라는 이미지 파일이 생성
# - 해당 이미지의 경로는 /content/drive/MyDrive/yolov4 에 있음

# %%
imShow('predictions.jpg')

# %% [markdown]
# ### 실험 차트 확인
# - 실험 차트는 chart_yolov4-custom.png 임
# - 해당 이미지 경로 역시 /content/drive/MyDrive/yolov4에 있음

# %%
# %cd /content/drive/MyDrive/yolov4/

# %%
# %pwd

# %%
# !chmod +x ./darknet

# %%
imShow('chart.png')

# %% [markdown]
# ### 실제 영상 실험

# %%
# !./darknet detector demo /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data /content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolov4/build/darknet/x64/backup/yolov4-custom_6000.weights -dont_show /content/drive/MyDrive/yolov4/build/darknet/x64/data/farm/video_12.mp4 -i 0 -out_filename old_weights_video12.avi

# %% [markdown]
# 생성된 avi 파일 다운로드 하기

# %%
download('new_weights_video01.avi')

# %% [markdown]
# ### web cam 실험
# 1. IP Webcam: https://play.google.com/store/apps/details?id=com.pas.webcam 다운로드
# 2. ngrok를 설치한다.
# IP Webcam에 있는 IP는 공개적이지 않아서 ngrok를 이용한다.
#
# 1) cmd를 킨다.
#
# 2) cd C:\Users\freet\ngrok
#
# 3) ngrok http {IP webcam IP}
#
# 4) https://6e92-175-204-239-48.jp.ngrok.io와 같이 생성된 웹 사이트를 이용해서
#
# 3. 아래의 코드를 통해 액세스한다.
#
# ※ cfg파일의 height, width를 32의 배수로 설정하면 정밀도가 증가하고 작은 물체를 감지할 수 있다(ex: 832)
#
# > 근데 아닌 것도 있는듯하다..

# %%
# !./darknet detector demo /content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data /content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg /content/drive/MyDrive/yolov4/build/darknet/x64/backup/250_dataset_6000/yolov4-custom_6000.weights -dont_show https://c36b-175-204-239-48.jp.ngrok.io/video?dummy=param.mjpg -i 0 -out_filename test_video_real.avi

# %% [markdown]
# ### 실시간 탐지
# => 노트북 카메라로 가능함
#
# => 휴대폰에서 코랩에 접속하여 실행시 휴대폰에서도 가능함
#
# 참고:
# https://colab.research.google.com/drive/1xdjyBiY75MAVRSjgmiqI7pbRLn58VrbE?usp=sharing#scrollTo=RPDr23YFW_7c

# %% [markdown]
# - 실시간 탐지에 필요한 함수

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import matplotlib.pyplot as plt
# %matplotlib inline


# import darknet functions to perform object detections
from darknet import *
# load in our YOLOv4 architecture network
network, class_names, class_colors = load_network("/content/drive/MyDrive/yolov4/build/darknet/x64/cfg/yolov4-custom.cfg", "/content/drive/MyDrive/yolov4/build/darknet/x64/data/obj.data", "/content/drive/MyDrive/yolov4/build/darknet/x64/backup/250_dataset_6000/yolov4-custom_6000.weights")
width = network_width(network)
height = network_height(network)

# darknet helper function to run detection on image
def darknet_helper(img, width, height):
  darknet_image = make_image(width, height, 3)
  img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  img_resized = cv2.resize(img_rgb, (width, height),
                              interpolation=cv2.INTER_LINEAR)

  # get image ratios to convert bounding boxes to proper size
  img_height, img_width, _ = img.shape
  width_ratio = img_width/width
  height_ratio = img_height/height

  # run model on darknet style image to get detections
  copy_image_from_bytes(darknet_image, img_resized.tobytes())
  detections = detect_image(network, class_names, darknet_image)
  free_image(darknet_image)
  return detections, width_ratio, height_ratio

# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }
      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);
      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();
      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }
      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# version1) box가 되어있지 않은 탐지된 이미지 저장하기
def image_url_download(url, count):#다운받을 data URIs, count
    from urllib import request
    
    with request.urlopen(url) as response:
        data = response.read()

    file_name = "image"+str(count)+".jpg"#저장할 이미지 이름

    with open(file_name, "wb") as f:
        f.write(data)

# version2) box가 포함된 탐지한 이미지 저장하기
def image_url_download2(img_url, bbox_url, count):#다운받을 data URIs, count
    from urllib import request
    from PIL import Image

    #인식된 이미지 저장
    with request.urlopen(img_url) as response:
        data = response.read()

    image_name = "image"+str(count)+".jpg"#저장할 이미지 이름

    with open(image_name, "wb") as f:
        f.write(data)

    #bbox 이미지 저장
    with request.urlopen(bbox_url) as response:
        data = response.read()

    boxImage_name = "box"+str(count)+".jpg"#저장할 이미지 이름

    with open(boxImage_name, "wb") as f:
        f.write(data)
    
    #인식된 이미지, bbox 이미지 합성
    finImage_name = "fin"+str(count)+".jpg"
    fg_img  = Image.open(boxImage_name).convert("RGBA")
    bg_img  = Image.open(image_name).convert("RGBA")
    fg_img_trans = Image.new("RGBA", bg_img.size)
    fg_img_trans.paste(fg_img, (0,0), mask=fg_img)
    new_img = Image.alpha_composite(bg_img, fg_img_trans).save(finImage_name,"png")

# %% [markdown]
# - 위에서 선언한 함수를 가지고 실제 탐지하기
#
# ---
#
# version1: box가 되어있지 않은 탐지된 이미지 저장하기<br>
# version2: box가 포함된 탐지한 이미지 저장하기

# %%
# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''

count = 1
while True:

    #프레임마다 human, animal, bird가 얼마나 관측되었는지 저장하는 변수
    human_cnt = 0
    animal_cnt = 0
    bird_cnt = 0

    js_reply = video_frame(label_html, bbox)


    if not js_reply:
        break
    # convert JS response to OpenCV Image
    frame = js_to_image(js_reply["img"])

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)

    # call our darknet helper on video frame
    detections, width_ratio, height_ratio = darknet_helper(frame, width, height)

    #version1 => box가 되어있지 않은 탐지된 이미지 저장하기
    # if len(detections) != 0 and len(bbox) != 0: #인식이 되었을 때
    #     img_link = js_reply.get('img') #box가 없는 사진 link
    #     count += 1   
    #     image_url_download(img_link, count)
    
    # version2 => box가 포함된 탐지한 이미지 저장하기 -> box사진과 인식된 이미지 합성
    if len(detections) != 0 and len(bbox) != 0:
        img_link = js_reply.get('img')
        count += 1
        image_url_download2(img_link, bbox, count)

    # loop through detections and draw them on transparent overlay image
    for label, confidence, bbox in detections:
        
         #프레임마다 human, animal, bird가 얼마나 관측되었는지 계산
        if label == 'human':
            human_cnt += 1
        elif label == 'animal':
            animal_cnt += 1
        elif label  == 'bird':
            bird_cnt += 1

        left, top, right, bottom = bbox2points(bbox)
        left, top, right, bottom = int(left * width_ratio), int(top * height_ratio), int(right * width_ratio), int(bottom * height_ratio)
        bbox_array = cv2.rectangle(bbox_array, (left, top), (right, bottom), class_colors[label], 2)
        bbox_array = cv2.putText(bbox_array, "{} [{:.2f}]".format(label, float(confidence)),
                            (left, top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                            class_colors[label], 2)
      
    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    print('human:', human_cnt)
    print('animal:', animal_cnt)
    print('bird:', bird_cnt)

        
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes

# %% [markdown]
# # 성능 향상시키기
# 1. 이미지 사이즈 동일화 416*416<br>
# https://daewoonginfo.blogspot.com/2019/05/opencv-python-resize.html<br>
# image_resize.py
# 2. 이미지 해상도 높이기(BilateralFilter)<br>
# https://deep-learning-study.tistory.com/164<br>
# bilateralFilter.py
# 3. 이미지 라벨링 다시하기
# 4. 학습 후 mAP 확인하기
